# %% [markdown]
# # College Students Food Choices Data Analysis
#
# In this project we will look at some interesting and variety of Food Habits and choices of College students .
#
#
# ![](http://bestfitness-news.com/wp-content/uploads/2021/05/15-Grim-Statistics-on-College-Students-Eating-Habits-NOOB.jpg)

# %%
# !pip install jovian opendatasets --upgrade --quiet

# %% [markdown]
# Let's begin by downloading the data, and listing the files within the dataset.

# %%
# Change this
dataset_url = 'https://www.kaggle.com/datasets/borapajo/food-choices'

# %%
import opendatasets as od
od.download(dataset_url)
# Out:
# Skipping, found downloaded files in "./food-choices" (use force=True to force download)

# %% [markdown]
# The dataset has been downloaded and extracted.

# %%
# Change this
data_dir = './food-choices'

# %%
import os
os.listdir(data_dir)
# Out:
# ['codebook_food.docx', 'food_coded.csv']

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
project_name = "College Students Food Habits " # change this (use lowercase letters and hyphens only)

# %% [markdown]
# ## Data Preparation and Cleaning
#
# #### Before Starting our analysis ,lets first prepare and clean our dataset.
#
# Here are the systematic steps we will take to clean our dataset.
#
# 1.Load the dataset into a data frame using Pandas.
#
# 2.Explore the number of rows and columns,ranges of values etc.
#
# 3.Handle missing,incorrect and invalid data.
#
# 4.Perform any additional steps(parsing dates,creating additional columns,merging multiple dataset etc).

# %%
import pandas as pd

# %%
food_coded_df = pd.read_csv('./food-choices/food_coded.csv')

# %%
df = food_coded_df.copy()

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df['Gender_uncoded'] = df['Gender'].replace([1],'Female' )
df['Gender_uncoded'] = df['Gender'].replace([2],'Male' )

# %%
df['Gender']

# %%
df['calories_day'] = df['calories_day'].replace([1.0],'I dont know how many calories i should consume' )
df['calories_day'] = df['calories_day'].replace([2.0],'It is not at all Important' )
df['calories_day'] = df['calories_day'].replace([3.0],'It is moderately Important' )
df['calories_day'] = df['calories_day'].replace([4.0],'It is very Important' )
df['calories_day'] = df['calories_day'].replace(['NaN'],'No Input' )

# %%
df['calories_day']
# Out:
# 0                             NaN
# 1      It is moderately Important
# 2            It is very Important
# 3      It is moderately Important
# 4      It is not at all Important
#                   ...
# 120          It is very Important
# 121    It is not at all Important
# 122                           NaN
# 123          It is very Important
# 124                           NaN
# Name: calories_day, Length: 125, dtype: object

# %%
df['comfort_food_reason_coded_1'] = df['comfort_food_reasons_coded.1']

# %%
df['comfort_food_reason_coded_1'] = df['comfort_food_reason_coded_1'].replace([1],'Stress' )
df['comfort_food_reason_coded_1'] = df['comfort_food_reason_coded_1'].replace([2],'Boredom' )
df['comfort_food_reason_coded_1'] = df['comfort_food_reason_coded_1'].replace([3],'Depression/Sadness' )
df['comfort_food_reason_coded_1'] = df['comfort_food_reason_coded_1'].replace([4],'Hunger' )
df['comfort_food_reason_coded_1'] = df['comfort_food_reason_coded_1'].replace([5],'Laziness' )
df['comfort_food_reason_coded_1'] = df['comfort_food_reason_coded_1'].replace([6],'Cold weather' )
df['comfort_food_reason_coded_1'] = df['comfort_food_reason_coded_1'].replace([7],'Happiness' )
df['comfort_food_reason_coded_1'] = df['comfort_food_reason_coded_1'].replace([8],'Watching TV' )
df['comfort_food_reason_coded_1'] = df['comfort_food_reason_coded_1'].replace([9],'None' )

# %%
 df['comfort_food_reason_coded_1']
# Out:
# 0                    None
# 1                  Stress
# 2                  Stress
# 3                 Boredom
# 4                  Stress
#               ...
# 120               Boredom
# 121    Depression/Sadness
# 122    Depression/Sadness
# 123             Happiness
# 124              Laziness
# Name: comfort_food_reason_coded_1, Length: 125, dtype: object

# %%
df['diet_current_coded']
# Out:
# 0      1
# 1      2
# 2      3
# 3      2
# 4      2
#       ..
# 120    2
# 121    2
# 122    2
# 123    1
# 124    1
# Name: diet_current_coded, Length: 125, dtype: int64

# %%
df['diet_current_uncoded'] =  df['diet_current_coded']

# %%
df['diet_current_uncoded'] = df['diet_current_uncoded'].replace([1],'healthy/balanced/moderated')
df['diet_current_uncoded'] = df['diet_current_uncoded'].replace([2],'unhealthy/cheap/too much/random')
df['diet_current_uncoded'] = df['diet_current_uncoded'].replace([3],'the same thing over and over')
df['diet_current_uncoded'] = df['diet_current_uncoded'].replace([4],'Unclear')

# %%
df['diet_current_uncoded']
# Out:
# 0           healthy/balanced/moderated
# 1      unhealthy/cheap/too much/random
# 2         the same thing over and over
# 3      unhealthy/cheap/too much/random
# 4      unhealthy/cheap/too much/random
#                     ...
# 120    unhealthy/cheap/too much/random
# 121    unhealthy/cheap/too much/random
# 122    unhealthy/cheap/too much/random
# 123         healthy/balanced/moderated
# 124         healthy/balanced/moderated
# Name: diet_current_uncoded, Length: 125, dtype: object

# %%
df['drink_uncoded'] = df['drink']

# %%
df['drink_uncoded'] = df['drink_uncoded'].replace([1.0],'Orange Juice')
df['drink_uncoded'] = df['drink_uncoded'].replace([2.0],'Soda')

# %%
df['eating_changes_uncoded'] = df['eating_changes_coded']

# %%
df['eating_changes_uncoded'] = df['eating_changes_uncoded'].replace([1],'Worse')
df['eating_changes_uncoded'] = df['eating_changes_uncoded'].replace([2],'Better')
df['eating_changes_uncoded'] = df['eating_changes_uncoded'].replace([3],'The Same')
df['eating_changes_uncoded'] = df['eating_changes_uncoded'].replace([4],'Unclear')

# %%
df['eating_out_uncoded'] = df['eating_out']

# %%
df['eating_out_uncoded'] = df['eating_out_uncoded'].replace([1],'Never')
df['eating_out_uncoded'] = df['eating_out_uncoded'].replace([2],'1-2 times')
df['eating_out_uncoded'] = df['eating_out_uncoded'].replace([3],'2-3 times')
df['eating_out_uncoded'] = df['eating_out_uncoded'].replace([4],'3-5 times')
df['eating_out_uncoded'] = df['eating_out_uncoded'].replace([5],'Everyday')

# %%
df['exercise_'] = df['exercise']

# %%
df['exercise_'] = df['exercise_'].replace([1],'Everyday')
df['exercise_'] = df['exercise_'].replace([2],'twice or thrice a week' )
df['exercise_'] = df['exercise_'].replace([3],'once a week')
df['exercise_'] = df['exercise_'].replace([4],'sometimes')
df['exercise_'] = df['exercise_'].replace([5],'Never')

# %%
df['grade_level_uncoded'] = df['grade_level']

# %%
df['grade_level_uncoded'] = df['grade_level_uncoded'].replace([1],'Freshman')
df['grade_level_uncoded'] = df['grade_level_uncoded'].replace([2],'Sophomore')
df['grade_level_uncoded'] = df['grade_level_uncoded'].replace([3],'Junior')
df['grade_level_uncoded'] = df['grade_level_uncoded'].replace([4],'Senior')

# %%
df['fruit_day'] = df['fruit_day'].replace([1],'very unlikely')
df['fruit_day'] = df['fruit_day'].replace([2],'unlikely')
df['fruit_day'] = df['fruit_day'].replace([3],'neutral')
df['fruit_day'] = df['fruit_day'].replace([4],'likely')
df['fruit_day'] = df['fruit_day'].replace([5],'very likely')

# %%
df['fruit_day']
# Out:
# 0      very likely
# 1           likely
# 2      very likely
# 3           likely
# 4           likely
#           ...
# 120    very likely
# 121         likely
# 122         likely
# 123    very likely
# 124        neutral
# Name: fruit_day, Length: 125, dtype: object

# %%
df['ideal_diet_coded'] =df['ideal_diet_coded'].replace([1],'portion control')
df['ideal_diet_coded'] =df['ideal_diet_coded'].replace([2],'eating healthier,adding fruit/veggies')
df['ideal_diet_coded'] =df['ideal_diet_coded'].replace([3],'balance')
df['ideal_diet_coded'] =df['ideal_diet_coded'].replace([4],'less sugar')
df['ideal_diet_coded'] =df['ideal_diet_coded'].replace([5],'home cooked/organic')
df['ideal_diet_coded'] =df['ideal_diet_coded'].replace([6],'current diet')
df['ideal_diet_coded'] =df['ideal_diet_coded'].replace([7],'more protein')
df['ideal_diet_coded'] =df['ideal_diet_coded'].replace([8],'unclear')

# %%
df['ideal_diet_coded']
# Out:
# 0                                    unclear
# 1                                    balance
# 2                               current diet
# 3      eating healthier,adding fruit/veggies
# 4      eating healthier,adding fruit/veggies
#                        ...
# 120                             current diet
# 121                      home cooked/organic
# 122    eating healthier,adding fruit/veggies
# 123                             current diet
# 124                                  balance
# Name: ideal_diet_coded, Length: 125, dtype: object

# %%
df['employment'] = df['employment'].replace([1],'full time')
df['employment'] = df['employment'].replace([2],'part time')
df['employment'] = df['employment'].replace([3],'Not working')

# %%
df['employment']
# Out:
# 0      Not working
# 1        part time
# 2      Not working
# 3      Not working
# 4        part time
#           ...
# 120      full time
# 121    Not working
# 122    Not working
# 123      part time
# 124      part time
# Name: employment, Length: 125, dtype: object

# %%
df['on_off_campus'] = df['on_off_campus'].replace([1],'On campus')
df['on_off_campus'] = df['on_off_campus'].replace([2],'Rent out of Campus')
df['on_off_campus'] = df['on_off_campus'].replace([3],'Live with my parents and commute')
df['on_off_campus'] = df['on_off_campus'].replace([4],'Own my own house')

# %%
df['on_off_campus']
# Out:
# 0                             On campus
# 1                             On campus
# 2                    Rent out of Campus
# 3                             On campus
# 4                             On campus
#                      ...
# 120    Live with my parents and commute
# 121                           On campus
# 122                           On campus
# 123                           On campus
# 124                           On campus
# Name: on_off_campus, Length: 125, dtype: object

# %%
df['nutritional_check']  = df['nutritional_check'].replace([1],'Never')
df['nutritional_check']  = df['nutritional_check'].replace([2],'On certain products only')
df['nutritional_check']  = df['nutritional_check'].replace([3],'Very rarely')
df['nutritional_check']  = df['nutritional_check'].replace([4],'On most products')
df['nutritional_check']  = df['nutritional_check'].replace([5],'On everything')

# %%
df['nutritional_check']
# Out:
# 0                 On everything
# 1              On most products
# 2              On most products
# 3      On certain products only
# 4                   Very rarely
#                  ...
# 120               On everything
# 121                 Very rarely
# 122                 Very rarely
# 123            On most products
# 124               On everything
# Name: nutritional_check, Length: 125, dtype: object

# %%
df['weight'] = df['weight'].replace(['lbs'],'')

# %%
df.reset_index(inplace = True)

# %%
df['GPA'] = pd.to_numeric(df.GPA[:], errors='coerce').fillna('Null')

# %%
df['GPA']
# Out:
# 0        2.4
# 1      3.654
# 2        3.3
# 3        3.2
# 4        3.5
#        ...
# 120      3.5
# 121      3.0
# 122    3.882
# 123      3.0
# 124      3.9
# Name: GPA, Length: 125, dtype: object

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# We will analyze the dataset using different plots,statistical methods and various methods using matplotlib, seaborn, numpy .
# >
# > - Compute the mean, sum, range and other interesting statistics for numeric columns
# > - Explore distributions of numeric columns using histograms etc.
# > - Explore relationship between columns using scatter plots, bar charts etc.
# > - Make a note of interesting insights from the exploratory analysis

# %% [markdown]
# Let's begin by importing`matplotlib.pyplot` and `seaborn`.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'
theme = plt.get_cmap('hsv')

# %% [markdown]
# **TODO** - Explore one or more columns by plotting a graph below, and add some explanation about it

# %%
pd.set_option('display.max_columns',None)
df.head()
# Out:
#    index    GPA  Gender  breakfast  calories_chicken  \
# 0      0    2.4       2          1               430
# 1      1  3.654       1          1               610
# 2      2    3.3       1          1               720
# 3      3    3.2       1          1               430
# 4      4    3.5       1          1               720
#
#                  calories_day  calories_scone  coffee  \
# 0                         NaN           315.0       1
# 1  It is moderately Important           420.0       2
# 2        It is very Important           420.0       2
# 3  It is moderately Important           420.0       2
# 4  It is not at all Important           420.0       2
#
#                        comfort_food        comfort_food_reasons  \
# 0                              none       we dont have comfort
# 1       chocolate, chips, ice cream        Stress, bored, anger
# 2   frozen yogurt, pizza, fast food             stress, sadness
# ...

# %%
df1 = df.select_dtypes(exclude=['object'])

# %%
for column in df1:
    plt.figure(figsize=(4,4))
    sns.boxplot(data = df1,x = column, color = 'skyblue' )
# Out:
# /tmp/ipykernel_40/2299509189.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(4,4))

# %% [markdown]
# ***These Boxplots gives us the idea of the range of Numerical columns and how the data is distributed in that range.***

# %% [markdown]
# ## Disturbution of our sample population based on grade level
# Let us see whether our data is balanced or not.
# let us see how many freshman,sophomores,Juniors,seniors are present in our Dataset.

# %%
df.grade_level_uncoded.value_counts().plot.bar()
plt.gca().set(title="Student distribution based on grade level",
             xlabel="Grade Level",ylabel="Student Count")
# Out:
# [Text(0.5, 1.0, 'Student distribution based on grade level'),
#  Text(0.5, 0, 'Grade Level'),
#  Text(0, 0.5, 'Student Count')]

# %%
plt.figure(figsize=(12,6))
plt.title('Percentage of Males and Females In dataset')
plt.pie(df['Gender'].value_counts(),labels =df['Gender'].value_counts().index
       ,autopct ='%1.1f%%' ,startangle = 180,colors=['crimson','teal']);

# %% [markdown]
# # Awareness of Importance of consuming calories per day and Nutrition
#
# lets analyze how much percent of students are aware of the importance of calorie consumption and how they feel about that.

# %% [markdown]
# ## Calorie count (per day)

# %%
df['calories_day'].value_counts()
# Out:
# It is moderately Important    63
# It is very Important          23
# It is not at all Important    20
# Name: calories_day, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('Awareness of Calories consumption')
plt.pie(df['calories_day'].value_counts(),labels =df['calories_day'].value_counts().index
       ,autopct ='%1.1f%%' ,startangle = 180,colors=['teal','crimson','orange']);

# %% [markdown]
# ***As we can see around 21 percent students feel it is very important and 60 percent feel it is moderately important and 19 percent feel it is not at all important***

# %% [markdown]
# ## Nutrition

# %%
plt.figure(figsize=(12,6))
plt.title('Awareness of Calories consumption')
plt.pie(df['nutritional_check'].value_counts(),labels =df['nutritional_check'].value_counts().index
       ,autopct ='%1.1f%%' ,startangle = 180,colors=['skyblue','crimson','orange','pink','green']);

# %% [markdown]
# ## Guessing the Calories in foods
#
# Let us see how many students guess the calories in food items accurately.Guessing accurately may show that student is aware of the calorie count of food items they consume or have knowledge of Calories of food items.

# %%
sns.violinplot(data = df, y = 'calories_scone',color= 'green')
x, y = 0 , 424
plt.plot(x,y,marker= 'o',markersize=20
         ,markerfacecolor='red')

# %% [markdown]
# ***Actual calories count of scone is 424 calories.***

# %%
sns.violinplot(data = df, y = 'calories_chicken',color= 'orange')
x,y = 0, 620
plt.plot(x,y,marker= 'o',markersize=20
         ,markerfacecolor='blue')

# %% [markdown]
# ***Actual calories count of chicken piadina is 620 calories.***

# %%
sns.violinplot(data = df, y = 'tortilla_calories',color= 'peachpuff')
x,y = 0,1000
plt.plot(x,y,marker= 'o',markersize=20
         ,markerfacecolor='black')

# %% [markdown]
# ***Actual calories count of burrito sandwhich from Chipolte  is 1000 calories.***

# %%
sns.violinplot(data = df, y = 'turkey_calories',color= 'lightyellow')
x,y = 0,640
plt.plot(x,y,marker= 'o',markersize=20
         ,markerfacecolor='red')

# %% [markdown]
# ***Actual calories count of Panera Bread Roasted Turkey and Avocado BLT  is 640 calories.***

# %% [markdown]
# **We can observe that most of the people guessed that calories of the food items near the actual calorie count.This shows that most people are aware of the calorie count of food items they eat or at least few food items.
# and of course there are some people who guessed the calorie count with a huge difference in number.**

# %% [markdown]
# ## Famous Cuisines Worldwide
# lets see the distribution of Ratings of famous cuisines such as Indian,Italian,Persian,Thai,Greek

# %%
fig, axes = plt.subplots(2, 3, figsize=(24, 12))

axes[0,0].set_title('Greek cuisine')
sns.boxplot(data=df ,x = 'greek_food',ax = axes[0,0],color = 'skyblue');

axes[0,1].set_title('Indian cuisine')
sns.boxplot(data = df , x ='indian_food',ax = axes[0,1],color = 'yellow');

axes[0,2].set_title('Italian cuisine')
sns.boxplot(data=df ,x = 'italian_food',ax = axes[0,2],color='red' );

axes[1,0].set_title('Persian cuisine')
sns.boxplot(data=df ,x = 'persian_food',ax = axes[1,0],color='orange' );


axes[1,1].set_title('Thai cuisine')
sns.boxplot(data=df ,x = 'thai_food',ax = axes[1,1],color='green' );

axes[1,2].set_title('Italaian food in violin plot')
sns.violinplot(x = 'italian_food',data =df,ax = axes[1,2],color = 'red');

# %% [markdown]
# ### Ratings of Famous Cuisines

# %%
rating_greek = df['greek_food'].mean()
rating_indian = df['indian_food'].mean()
rating_italian = df['italian_food'].mean()
rating_persian = df['persian_food'].mean()
rating_thai = df['thai_food'].mean()
ratings =  [rating_greek,rating_indian,rating_italian,
            rating_persian,rating_thai]
cuisines = ['greek','indian','italian','persian','thai']

# %%
sns.barplot(x = ratings,y = cuisines,palette = 'rocket_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# As we can the most famous and widely loved cuisine is Italian followed Greek and Thai.India stands fourth and Persian at fifth.

# %% [markdown]
# # Diet

# %%
df['diet_current_uncoded']
# Out:
# 0           healthy/balanced/moderated
# 1      unhealthy/cheap/too much/random
# 2         the same thing over and over
# 3      unhealthy/cheap/too much/random
# 4      unhealthy/cheap/too much/random
#                     ...
# 120    unhealthy/cheap/too much/random
# 121    unhealthy/cheap/too much/random
# 122    unhealthy/cheap/too much/random
# 123         healthy/balanced/moderated
# 124         healthy/balanced/moderated
# Name: diet_current_uncoded, Length: 125, dtype: object

# %%
plt.figure(figsize=(12,6))
plt.rc('font',size = 12)
plt.title("Diet Description")
plt.pie(df['diet_current_uncoded'].value_counts(),labels =df['diet_current_uncoded'].value_counts().index
       ,autopct ='%1.1f%%' ,startangle =180 ,colors=['darkorange','forestgreen','salmon','grey']);

# %% [markdown]
# ***Around 50 percent students eat unhealthy or cheap or too much and random food.***

# %% [markdown]
# ***Word "drink"***

# %%
df['drink_uncoded']
# Out:
# 0      Orange Juice
# 1              Soda
# 2      Orange Juice
# 3              Soda
# 4              Soda
#            ...
# 120            Soda
# 121    Orange Juice
# 122    Orange Juice
# 123            Soda
# 124    Orange Juice
# Name: drink_uncoded, Length: 125, dtype: object

# %%
plt.figure(figsize=(12,6))
plt.rc('font',size = 12)
plt.title("Popular Drink")
plt.pie(df['drink_uncoded'].value_counts(),labels =df['drink_uncoded'].value_counts().index
       ,autopct ='%1.1f%%' ,startangle =180 ,colors=['royalblue','darkorange']);

# %% [markdown]
# ***Clearly Soda being more popular drink than Orange Juice justifies  our previous analysis of diet showing 50 percent people having unhealthy diet***

# %% [markdown]
# ## Analysis of Eating Habits

# %% [markdown]
# #### Let's see the what eating changes students have gone through.

# %%
df['eating_changes_uncoded']
# Out:
# 0         Worse
# 1         Worse
# 2         Worse
# 3         Worse
# 4      The Same
#          ...
# 120       Worse
# 121       Worse
# 122       Worse
# 123       Worse
# 124      Better
# Name: eating_changes_uncoded, Length: 125, dtype: object

# %%
plt.figure(figsize=(12,6))
plt.rc('font',size = 12)
plt.title("Eating Changes")
plt.pie(df['eating_changes_uncoded'].value_counts(),labels =df['eating_changes_uncoded'].value_counts().index
       ,autopct ='%1.1f%%' ,startangle =180 ,colors=['red','skyblue','orange','violet']);

# %% [markdown]
# ***sixty percent students expressed decline in healthy eating habits.Twenty eight feel improve in their eating habits.around Nine percent feel No major changes and Two percent are Unclear .***

# %% [markdown]
# ### Eating_out Habits

# %%
plt.figure(figsize=(12,6))
plt.rc('font',size = 12)
plt.title("Frequency of Eating out in a typical week")
plt.pie(df['eating_out_uncoded'].value_counts(),labels =df['eating_out_uncoded'].value_counts().index
       ,autopct ='%1.1f%%' ,startangle =0 ,colors=['orange','darksalmon','green','gold','red','green']);

# %% [markdown]
# ***Majority of students eat outside on an average of 1-2 times in a typical week***

# %% [markdown]
# ## Exercise and Physical Health

# %%
plt.figure(figsize=(12,6))
plt.rc('font',size = 12)
plt.title("Exercise in regular week")
plt.pie(df['exercise_'].value_counts(),labels =df['exercise_'].value_counts().index
       ,autopct ='%1.1f%%' ,startangle =0 ,colors=['skyblue','orange','green']);

# %% [markdown]
# ***All the students workout regularly***

# %% [markdown]
# ## Ideal Diet
#
# let us see what students feel should their Ideal diet be.

# %%
diet = df.ideal_diet_coded.value_counts()

# %%
plt.figure(figsize=(24,12))
sns.barplot(x = diet.index,y = diet,palette = 'Spectral' )
# Out:
# <AxesSubplot:ylabel='ideal_diet_coded'>

# %% [markdown]
# ## Employment status of students

# %%
a = df.employment.value_counts()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = a.index,y = a,palette = 'hls' )
# Out:
# <AxesSubplot:ylabel='employment'>

# %% [markdown]
# ## Living - On or Off Campus

# %%
living = df.on_off_campus.value_counts()

# %%
plt.figure(figsize=(16,6))
sns.barplot(x = living.index,y = living,palette = 'husl' )
# Out:
# <AxesSubplot:ylabel='on_off_campus'>

# %% [markdown]
# Heat maps shows us how correlated are the columns with each other.

# %%
sns.set(rc={'figure.figsize':(69,69)})
sns.heatmap(df.corr(), cmap='Reds', annot=True)
plt.title('Correlation Matrix');

# %% [markdown]
# ## Asking and Answering Questions
#
# Lets us find answers using exploratory data visualization for the questions below.

# %% [markdown]
# #### Q1: what is the average diet of the college students.

# %%
sns.set(rc={'figure.figsize':(10,10)})
plt.hist(df['diet_current_coded'])
# Out:
# (array([50.,  0.,  0., 60.,  0.,  0., 10.,  0.,  0.,  5.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 1 – healthy/balanced/moderated
#
# 2 – unhealthy/cheap/too much/random
#
# Around 48 percent participants reported that they consume unhealthy or cheap or random diet which may be because of the limited and cheap availability of the unhealthy food such as drinks,snacks,sugary items and much more in and nearby the college.There is also a good percent around (40%) reported that they consume healthy food,or healthy and unhealthy food in a balanced and moderated way.

# %% [markdown]
# #### Q2: What factors drives us to eat?

# %% [markdown]
# ### Comfort foods

# %%
df['comfort_food_reason_coded_1']
# Out:
# 0                    None
# 1                  Stress
# 2                  Stress
# 3                 Boredom
# 4                  Stress
#               ...
# 120               Boredom
# 121    Depression/Sadness
# 122    Depression/Sadness
# 123             Happiness
# 124              Laziness
# Name: comfort_food_reason_coded_1, Length: 125, dtype: object

# %%
fig1, ax1 = plt.subplots(figsize=(12, 8))
plt.rc('font',size=12)
theme = plt.get_cmap('hsv')
ax1.set_prop_cycle("color", [theme(1. * i / 10)
                             for i in range(0,10)])
plt.pie(df['comfort_food_reason_coded_1'].value_counts(),labels = df['comfort_food_reason_coded_1'].value_counts().index
 ,startangle = 0,autopct ='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7feb02e504c0>,
# ...
#  [Text(0.2601489135374878, 1.0687949021141825, 'Boredom'),
#   Text(-1.071979562467377, -0.2466978266062581, 'Stress'),
#   Text(-0.06906955709217558, -1.097829402176445, 'Depression/Sadness'),
#   Text(0.7011664053880496, -0.8475645532673021, 'Laziness'),
#   Text(0.9212808574392928, -0.6010337608786397, 'None'),
#   Text(1.041808141377795, -0.3530379534256115, 'Happiness'),
#   Text(1.0913261734466653, -0.1378665410832483, 'Hunger'),
#   Text(1.0996526086639065, -0.027643086995952023, 'Cold weather')],
#  [Text(0.14189940738408424, 0.5829790375168268, '42.4%'),
#   Text(-0.5847161249822055, -0.13456245087614077, '22.4%'),
#   Text(-0.0376743038684594, -0.5988160375507882, '18.4%'),
#   Text(0.3824544029389361, -0.46230793814580107, '5.6%'),
#   Text(0.5025168313305233, -0.32783659684289435, '4.0%'),
#   Text(0.56825898620607, -0.19256615641396987, '4.0%'),
#   Text(0.5952688218799992, -0.0751999314999536, '2.4%'),
# ...

# %% [markdown]
# **We can see that around 40 percent of people consume food to beat boredom, 22 percent consume food due to stress, 18 percent people consume due to Depression/Sadness, 5 percent due to laziness, 4 percent because of Happiness and coming to the most interesting part only 2.4 percent people consume food because they feel hungry and rest due to other or No reason.**
#
# ***It is very interesting and thought provoking to find out that how there are many things that makes us consume food apart from Hunger such as our Mood,Stress, Laziness, Weather and so on. ***

# %% [markdown]
# #### Q3: What are the eating preferences of college students for health?

# %%
diet = df.ideal_diet_coded.value_counts()

# %%
plt.figure(figsize=(24,12))
sns.barplot(x = diet.index,y = diet,palette = 'Spectral' )
# Out:
# <AxesSubplot:ylabel='ideal_diet_coded'>

# %% [markdown]
# Majority of the students have formed the habit of adding fruits/veggies to their diet which is a good practice. Choosing food according to taste preference seems to be the hallmark of college students. An interesting finding was that a large number of students reported they ate fresh fruits frequently, while they also consumed processed food. This contradictory health practice may be because of the limited food options available on campus. Students consumed a lot of processed food; however, they tried to maintain their nutrition level by choosing fresh fruit options available to them.Some students also acknowledge that Sugar is unhealthy and they opt for less sugar diet.

# %% [markdown]
# #### Q4: TODO - ask a question here and answer it below

# %% [markdown]
# ## Inferences and Conclusion
#
# About one-third of college student participants reported that they were from 6 to 50+ pounds of overweight. Even though students were knowledgeable about food containing additives, perils of fast food, unhealthiness of processed food and soda, they intermingled processed and fast food based on taste preference and convenience with fruits and salads. Although many participants showed good eating habits and adequate knowledge of nutritional requirements, the need was discovered to investigate further about different factors that contribute to their eating habits and their knowledge. In addition, it would be beneficial to research what health education practices can be placed to help guide their eating habits and promote overall health. Providing health, nutrition related courses and using technology as a means to educate the new generation could be effective and used for future learning.
#
#
#
# **Limitations**
#
# A limitation to this Analysis is the small sample size of 121 participants in about 2000-student population. The college cafeteria is the main dining place on campus where most traditional undergraduate students who have on-campus meal plan eat every day. Non-traditional or commuters were underrepresented. Another limitation was that the responses could have been biased because students were already going or coming from eating at a buffet style location. Since this survey was gathering information regarding nutritional requirements,some student's responses might have differed compared to those students who would cook at home or in their hostels.
#
#
# **References**
#
# https://www.noobgains.com/college-student-diet-statistics/
